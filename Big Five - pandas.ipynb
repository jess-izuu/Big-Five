# %%
import pandas as pd
import seaborn as sns

# this shows chart outputs within the notebook
# %matplotlib inline

# %%
#read in data 
filepath = "data-final.csv"

df = pd.read_csv(filepath, delimiter='\t')
df.describe()
# Out:
#                EXT1          EXT2          EXT3          EXT4          EXT5  \
# count  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06
# mean   2.648067e+00  2.773115e+00  3.288349e+00  3.140595e+00  3.276960e+00
# std    1.264407e+00  1.323943e+00  1.215006e+00  1.237442e+00  1.277593e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 50%    3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# 75%    4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00
# max    5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
#
#                EXT6          EXT7          EXT8          EXT9         EXT10  \
# count  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06
# mean   2.401100e+00  2.771744e+00  3.414818e+00  2.963740e+00  3.556469e+00
# ...

# %%
df.head(5)
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  \
# 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0
# 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0
# 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0
# 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0
# 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0
#
#            ...                       dateload  screenw  screenh  introelapse  \
# 0          ...            2016-03-03 02:01:01    768.0   1024.0          9.0
# 1          ...            2016-03-03 02:01:20   1360.0    768.0         12.0
# 2          ...            2016-03-03 02:01:56   1366.0    768.0          3.0
# 3          ...            2016-03-03 02:02:02   1920.0   1200.0        186.0
# 4          ...            2016-03-03 02:02:57   1366.0    768.0          8.0
#
#    testelapse  endelapse  IPC  country  lat_appx_lots_of_err  \
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0
# 5         3.0   3.0   4.0   2.0   4.0   2.0   2.0   3.0   3.0    4.0
# 6         4.0   3.0   4.0   3.0   3.0   3.0   5.0   3.0   4.0    3.0
# 7         3.0   1.0   5.0   2.0   5.0   2.0   5.0   2.0   3.0    2.0
# 8         2.0   2.0   3.0   3.0   4.0   2.0   2.0   2.0   4.0    4.0
# 9         1.0   5.0   3.0   5.0   2.0   3.0   2.0   4.0   5.0    4.0
# 10        3.0   3.0   2.0   3.0   3.0   2.0   4.0   3.0   3.0    5.0
# 11        3.0   1.0   5.0   3.0   5.0   1.0   5.0   5.0   5.0    3.0
# ...

# %%
df.columns
# Out:
# Index(['EXT1', 'EXT2', 'EXT3', 'EXT4', 'EXT5', 'EXT6', 'EXT7', 'EXT8', 'EXT9',
#        'EXT10',
#        ...
#        'dateload', 'screenw', 'screenh', 'introelapse', 'testelapse',
#        'endelapse', 'IPC', 'country', 'lat_appx_lots_of_err',
#        'long_appx_lots_of_err'],
#       dtype='object', length=110)

# %%
len(df)
# Out:
# 1015341

# %%
df.shape
# Out:
# (1015341, 110)

# %%
df.dtypes
# Out:
# EXT1                     float64
# EXT2                     float64
# EXT3                     float64
# EXT4                     float64
# EXT5                     float64
# EXT6                     float64
# EXT7                     float64
# EXT8                     float64
# EXT9                     float64
# EXT10                    float64
# EST1                     float64
# EST2                     float64
# EST3                     float64
# EST4                     float64
# EST5                     float64
# EST6                     float64
# EST7                     float64
# EST8                     float64
# EST9                     float64
# EST10                    float64
# AGR1                     float64
# AGR2                     float64
# AGR3                     float64
# AGR4                     float64
# AGR5                     float64
# AGR6                     float64
# AGR7                     float64
# AGR8                     float64
# ...

# %%
df['EXT1'].value_counts()
# Out:
# 3.0    288622
# 1.0    249711
# 2.0    199165
# 4.0    191638
# 5.0     80702
# 0.0      3720
# Name: EXT1, dtype: int64

# %%
# total number of non-missing values in each column
df.isnull().sum()
# Out:
# EXT1                     1783
# EXT2                     1783
# EXT3                     1783
# EXT4                     1783
# EXT5                     1783
# EXT6                     1783
# EXT7                     1783
# EXT8                     1783
# EXT9                     1783
# EXT10                    1783
# EST1                     1783
# EST2                     1783
# EST3                     1783
# EST4                     1783
# EST5                     1783
# EST6                     1783
# EST7                     1783
# EST8                     1783
# EST9                     1783
# EST10                    1783
# AGR1                     1783
# AGR2                     1783
# AGR3                     1783
# AGR4                     1783
# AGR5                     1783
# AGR6                     1783
# AGR7                     1783
# AGR8                     1783
# AGR9                     1783
# AGR10                    1783
#                          ...
# ...

# %%
sns.countplot(df['EXT1'])

# %%
sns.countplot(df['EXT2'])

# %%
sns.countplot(df['EXT3'])

# %%
sns.barplot(x=df['screenw'], y=df['screenh'], ci=None)

# %%
def assess_NA(data):
    """
    Returns a pandas dataframe denoting the total number of NA values and the percentage of NA values in each column.
    The column names are noted on the index.
    
    Parameters
    ----------
    data: dataframe
    """
    # pandas series denoting features and the sum of their null values
    null_sum = data.isnull().sum()# instantiate columns for missing data
    total = null_sum.sort_values(ascending=False)
    percent = ( ((null_sum / len(data.index))*100).round(2) ).sort_values(ascending=False)
    
    # concatenate along the columns to create the complete dataframe
    df_NA = pd.concat([total, percent], axis=1, keys=['Number of NA', 'Percent NA'])
    
    # drop rows that don't have any missing data; omit if you want to keep all rows
    df_NA = df_NA[ (df_NA.T != 0).any() ]
    
    return df_NA

# %%
#missing data
assess_NA(df)
# Out:
#              Number of NA  Percent NA
# introelapse          2066        0.20
# screenh              2066        0.20
# screenw              2066        0.20
# EXT5_E               1783        0.18
# CSN10                1783        0.18
# AGR9                 1783        0.18
# AGR10                1783        0.18
# CSN1                 1783        0.18
# CSN2                 1783        0.18
# CSN3                 1783        0.18
# CSN4                 1783        0.18
# CSN5                 1783        0.18
# CSN6                 1783        0.18
# CSN7                 1783        0.18
# CSN8                 1783        0.18
# CSN9                 1783        0.18
# OPN2                 1783        0.18
# OPN1                 1783        0.18
# AGR7                 1783        0.18
# OPN3                 1783        0.18
# OPN4                 1783        0.18
# OPN5                 1783        0.18
# OPN6                 1783        0.18
# OPN7                 1783        0.18
# ...

# %%
# Drop rows with null values
df = df.dropna(axis=0)

# Drop column_1 rows with null values
df['EXT1'] = df['EXT1'].dropna(axis=0)
df['EXT2'] = df['EXT2'].dropna(axis=0)
df['EXT3'] = df['EXT3'].dropna(axis=0)
df['EXT4'] = df['EXT4'].dropna(axis=0)
df['EXT5'] = df['EXT5'].dropna(axis=0)
df['EXT6'] = df['EXT6'].dropna(axis=0)
df['EXT7'] = df['EXT7'].dropna(axis=0)
df['EXT8'] = df['EXT8'].dropna(axis=0)
df['EXT9'] = df['EXT9'].dropna(axis=0)
df['EXT10'] = df['EXT10'].dropna(axis=0)

# %%
# total number of non-missing values in each column
df.isnull().sum()
# Out:
# EXT1                     0
# EXT2                     0
# EXT3                     0
# EXT4                     0
# EXT5                     0
# EXT6                     0
# EXT7                     0
# EXT8                     0
# EXT9                     0
# EXT10                    0
# EST1                     0
# EST2                     0
# EST3                     0
# EST4                     0
# EST5                     0
# EST6                     0
# EST7                     0
# EST8                     0
# EST9                     0
# EST10                    0
# AGR1                     0
# AGR2                     0
# AGR3                     0
# AGR4                     0
# AGR5                     0
# AGR6                     0
# AGR7                     0
# AGR8                     0
# AGR9                     0
# AGR10                    0
#                         ..
# CSN1_E                   0
# CSN2_E                   0
# CSN3_E                   0
# ...

# %%
#missing data
assess_NA(df)
# Out:
# Empty DataFrame
# Columns: [Number of NA, Percent NA]
# Index: []

# %%
#Convert ranking answers to ints 
df['EXT1'] = df['EXT1'].astype(int)
df['EXT2'] = df['EXT2'].astype(int)
df['EXT3'] = df['EXT3'].astype(int)
df['EXT4'] = df['EXT4'].astype(int)
df['EXT5'] = df['EXT5'].astype(int)
df['EXT6'] = df['EXT6'].astype(int)
df['EXT7'] = df['EXT7'].astype(int)
df['EXT8'] = df['EXT8'].astype(int)
df['EXT9'] = df['EXT9'].astype(int)
df['EXT10'] = df['EXT10'].astype(int)

df['CSN1'] = df['CSN1'].astype(int)
df['CSN2'] = df['CSN2'].astype(int)
df['CSN3'] = df['CSN3'].astype(int)
df['CSN4'] = df['CSN4'].astype(int)
df['CSN5'] = df['CSN5'].astype(int)
df['CSN6'] = df['CSN6'].astype(int)
df['CSN7'] = df['CSN7'].astype(int)
df['CSN8'] = df['CSN8'].astype(int)
df['CSN9'] = df['CSN9'].astype(int)
df['CSN10'] = df['CSN10'].astype(int)

df['OPN1'] = df['OPN1'].astype(int)
df['OPN2'] = df['OPN2'].astype(int)
df['OPN3'] = df['OPN3'].astype(int)
df['OPN4'] = df['OPN4'].astype(int)
df['OPN5'] = df['OPN5'].astype(int)
df['OPN6'] = df['OPN6'].astype(int)
df['OPN7'] = df['OPN7'].astype(int)
df['OPN8'] = df['OPN8'].astype(int)
df['OPN9'] = df['OPN9'].astype(int)
df['OPN10'] = df['OPN10'].astype(int)

df['AGR1'] = df['AGR1'].astype(int)
df['AGR2'] = df['AGR2'].astype(int)
df['AGR3'] = df['AGR3'].astype(int)
df['AGR4'] = df['AGR4'].astype(int)
df['AGR5'] = df['AGR5'].astype(int)
df['AGR6'] = df['AGR6'].astype(int)
df['AGR7'] = df['AGR7'].astype(int)
df['AGR8'] = df['AGR8'].astype(int)
df['AGR9'] = df['AGR9'].astype(int)
df['AGR10'] = df['AGR10'].astype(int)

df['EST1'] = df['EST1'].astype(int)
df['EST2'] = df['EST2'].astype(int)
df['EST3'] = df['EST3'].astype(int)
df['EST4'] = df['EST4'].astype(int)
df['EST5'] = df['EST5'].astype(int)
df['EST6'] = df['EST6'].astype(int)
df['EST7'] = df['EST7'].astype(int)
df['EST8'] = df['EST8'].astype(int)
df['EST9'] = df['EST9'].astype(int)
df['EST10'] = df['EST10'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5caf5b84fcc9> in <module>()
#       1 #Convert ranking answers to ints
# ----> 2 df['EXT1'] = df['EXT1'].astype(int)
#       3 df['EXT2'] = df['EXT2'].astype(int)
#       4 df['EXT3'] = df['EXT3'].astype(int)
#       5 df['EXT4'] = df['EXT4'].astype(int)
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# EXT1                       int64
# EXT2                       int64
# EXT3                       int64
# EXT4                       int64
# EXT5                       int64
# EXT6                       int64
# EXT7                       int64
# EXT8                       int64
# EXT9                       int64
# EXT10                      int64
# EST1                       int64
# EST2                       int64
# EST3                       int64
# EST4                       int64
# EST5                       int64
# EST6                       int64
# EST7                       int64
# EST8                       int64
# EST9                       int64
# EST10                      int64
# AGR1                       int64
# AGR2                       int64
# AGR3                       int64
# AGR4                       int64
# AGR5                       int64
# AGR6                       int64
# AGR7                       int64
# AGR8                       int64
# ...

# %%
#SaveData to .csv
df.to_csv('Big_Five_no_delimit.csv',index=False)

# %%
# save cleaned data to Excel
# engine" parameter tells file what Excel format encoding (.xls, .xlsx) to create

writer = pd.ExcelWriter('Big_Five_cleaned.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1', index=False)
writer.save()

# %% [markdown]
# # Average Time for Each Question

# %%
#Average amount of time to answer each question in extraversion
ext_list = []
ext_list.append(df['EXT1_E'].mean()/1000)
ext_list.append(df['EXT2_E'].mean()/1000)
ext_list.append(df['EXT3_E'].mean()/1000)
ext_list.append(df['EXT4_E'].mean()/1000)
ext_list.append(df['EXT5_E'].mean()/1000)
ext_list.append(df['EXT6_E'].mean()/1000)
ext_list.append(df['EXT7_E'].mean()/1000)
ext_list.append(df['EXT8_E'].mean()/1000)
ext_list.append(df['EXT9_E'].mean()/1000)
ext_list.append(df['EXT10_E'].mean()/1000)

# %%
#Average amount of time to answer each question in conscientious
csn_list = []
csn_list.append(df['CSN1_E'].mean()/1000)
csn_list.append(df['CSN2_E'].mean()/1000)
csn_list.append(df['CSN3_E'].mean()/1000)
csn_list.append(df['CSN4_E'].mean()/1000)
csn_list.append(df['CSN5_E'].mean()/1000)
csn_list.append(df['CSN6_E'].mean()/1000)
csn_list.append(df['CSN7_E'].mean()/1000)
csn_list.append(df['CSN8_E'].mean()/1000)
csn_list.append(df['CSN9_E'].mean()/1000)
csn_list.append(df['CSN10_E'].mean()/1000)

# %%
#Average amount of time to answer each question in openness
opn_list = []
opn_list.append(df['OPN1_E'].mean()/1000)
opn_list.append(df['OPN2_E'].mean()/1000)
opn_list.append(df['OPN3_E'].mean()/1000)
opn_list.append(df['OPN4_E'].mean()/1000)
opn_list.append(df['OPN5_E'].mean()/1000)
opn_list.append(df['OPN6_E'].mean()/1000)
opn_list.append(df['OPN7_E'].mean()/1000)
opn_list.append(df['OPN8_E'].mean()/1000)
opn_list.append(df['OPN9_E'].mean()/1000)
opn_list.append(df['OPN10_E'].mean()/1000)

# %%
#Average amount of time to answer each question in agreeableness
agr_list = []
agr_list.append(df['AGR1_E'].mean()/1000)
agr_list.append(df['AGR2_E'].mean()/1000)
agr_list.append(df['AGR3_E'].mean()/1000)
agr_list.append(df['AGR4_E'].mean()/1000)
agr_list.append(df['AGR5_E'].mean()/1000)
agr_list.append(df['AGR6_E'].mean()/1000)
agr_list.append(df['AGR7_E'].mean()/1000)
agr_list.append(df['AGR8_E'].mean()/1000)
agr_list.append(df['AGR9_E'].mean()/1000)
agr_list.append(df['AGR10_E'].mean()/1000)

# %%
#Average amount of time to answer each question in neuroticism (emotional stability)
est_list = []
est_list.append(df['EST1_E'].mean()/1000)
est_list.append(df['EST2_E'].mean()/1000)
est_list.append(df['EST3_E'].mean()/1000)
est_list.append(df['EST4_E'].mean()/1000)
est_list.append(df['EST5_E'].mean()/1000)
est_list.append(df['EST6_E'].mean()/1000)
est_list.append(df['EST7_E'].mean()/1000)
est_list.append(df['EST8_E'].mean()/1000)
est_list.append(df['EST9_E'].mean()/1000)
est_list.append(df['EST10_E'].mean()/1000)

# %%
avgTime_list = pd.DataFrame(
    {'Extraversion': ext_list,
     'Conscientiousness': csn_list,
     'Openness': opn_list,
     'Neuroticism': est_list,
     'Agreeableness': agr_list
    })

# %%
avgTime_list

# %%
avgTime_list.min()

# %%
avgTime_list.max()

# %% [markdown]
# # Std Time for Each Question

# %%
#Standard Dev from mean - amount of time to answer each question 
extSD_list = []
extSD_list.append(df['EXT1_E'].std()/1000)
extSD_list.append(df['EXT2_E'].std()/1000)
extSD_list.append(df['EXT3_E'].std()/1000)
extSD_list.append(df['EXT4_E'].std()/1000)
extSD_list.append(df['EXT5_E'].std()/1000)
extSD_list.append(df['EXT6_E'].std()/1000)
extSD_list.append(df['EXT7_E'].std()/1000)
extSD_list.append(df['EXT8_E'].std()/1000)
extSD_list.append(df['EXT9_E'].std()/1000)
extSD_list.append(df['EXT10_E'].std()/1000)

csnSD_list = []
csnSD_list.append(df['CSN1_E'].std()/1000)
csnSD_list.append(df['CSN2_E'].std()/1000)
csnSD_list.append(df['CSN3_E'].std()/1000)
csnSD_list.append(df['CSN4_E'].std()/1000)
csnSD_list.append(df['CSN5_E'].std()/1000)
csnSD_list.append(df['CSN6_E'].std()/1000)
csnSD_list.append(df['CSN7_E'].std()/1000)
csnSD_list.append(df['CSN8_E'].std()/1000)
csnSD_list.append(df['CSN9_E'].std()/1000)
csnSD_list.append(df['CSN10_E'].std()/1000)

opnSD_list = []
opnSD_list.append(df['OPN1_E'].std()/1000)
opnSD_list.append(df['OPN2_E'].std()/1000)
opnSD_list.append(df['OPN3_E'].std()/1000)
opnSD_list.append(df['OPN4_E'].std()/1000)
opnSD_list.append(df['OPN5_E'].std()/1000)
opnSD_list.append(df['OPN6_E'].std()/1000)
opnSD_list.append(df['OPN7_E'].std()/1000)
opnSD_list.append(df['OPN8_E'].std()/1000)
opnSD_list.append(df['OPN9_E'].std()/1000)
opnSD_list.append(df['OPN10_E'].std()/1000)

agrSD_list = []
agrSD_list.append(df['AGR1_E'].std()/1000)
agrSD_list.append(df['AGR2_E'].std()/1000)
agrSD_list.append(df['AGR3_E'].std()/1000)
agrSD_list.append(df['AGR4_E'].std()/1000)
agrSD_list.append(df['AGR5_E'].std()/1000)
agrSD_list.append(df['AGR6_E'].std()/1000)
agrSD_list.append(df['AGR7_E'].std()/1000)
agrSD_list.append(df['AGR8_E'].std()/1000)
agrSD_list.append(df['AGR9_E'].std()/1000)
agrSD_list.append(df['AGR10_E'].std()/1000)

estSD_list = []
estSD_list.append(df['EST1_E'].std()/1000)
estSD_list.append(df['EST2_E'].std()/1000)
estSD_list.append(df['EST3_E'].std()/1000)
estSD_list.append(df['EST4_E'].std()/1000)
estSD_list.append(df['EST5_E'].std()/1000)
estSD_list.append(df['EST6_E'].std()/1000)
estSD_list.append(df['EST7_E'].std()/1000)
estSD_list.append(df['EST8_E'].std()/1000)
estSD_list.append(df['EST9_E'].std()/1000)
estSD_list.append(df['EST10_E'].std()/1000)

# %%
avgTimeSD_list = pd.DataFrame(
    {'Extraversion': extSD_list,
     'Conscientiousness': csnSD_list,
     'Openness': opnSD_list,
     'Neuroticism': estSD_list,
     'Agreeableness': agrSD_list
    })

# %%
avgTimeSD_list
# Out:
#    Agreeableness  Conscientiousness  Extraversion  Neuroticism     Openness
# 0    1741.056030        1314.490887   4887.845117  1241.508835   931.681726
# 1     718.069677         572.528449    562.532179   627.180092  1221.541655
# 2     259.010178        1257.300676   2328.112677   709.929309   376.368730
# 3     757.183830         721.609442    338.186038  2401.873266  3047.609982
# 4    2180.418443        1014.837491    602.378568  2181.408317   341.401395
# 5     350.588140        2243.966302    567.553191   701.385319   564.269154
# 6     666.975940         268.993457   2190.123913   431.757236   584.198710
# 7    1399.846879         565.574040    368.270685  2154.117938   262.974763
# 8     163.231314         404.109436    248.150849   445.318623   429.890560
# 9     304.489742        2205.455770   2144.985269   170.542135   440.822490

# %% [markdown]
# # Median Time for Each Question

# %%
extMD_list = []
extMD_list.append(df['EXT1_E'].median()/1000)
extMD_list.append(df['EXT2_E'].median()/1000)
extMD_list.append(df['EXT3_E'].median()/1000)
extMD_list.append(df['EXT4_E'].median()/1000)
extMD_list.append(df['EXT5_E'].median()/1000)
extMD_list.append(df['EXT6_E'].median()/1000)
extMD_list.append(df['EXT7_E'].median()/1000)
extMD_list.append(df['EXT8_E'].median()/1000)
extMD_list.append(df['EXT9_E'].median()/1000)
extMD_list.append(df['EXT10_E'].median()/1000)

csnMD_list = []
csnMD_list.append(df['CSN1_E'].median()/1000)
csnMD_list.append(df['CSN2_E'].median()/1000)
csnMD_list.append(df['CSN3_E'].median()/1000)
csnMD_list.append(df['CSN4_E'].median()/1000)
csnMD_list.append(df['CSN5_E'].median()/1000)
csnMD_list.append(df['CSN6_E'].median()/1000)
csnMD_list.append(df['CSN7_E'].median()/1000)
csnMD_list.append(df['CSN8_E'].median()/1000)
csnMD_list.append(df['CSN9_E'].median()/1000)
csnMD_list.append(df['CSN10_E'].median()/1000)


opnMD_list = []
opnMD_list.append(df['OPN1_E'].median()/1000)
opnMD_list.append(df['OPN2_E'].median()/1000)
opnMD_list.append(df['OPN3_E'].median()/1000)
opnMD_list.append(df['OPN4_E'].median()/1000)
opnMD_list.append(df['OPN5_E'].median()/1000)
opnMD_list.append(df['OPN6_E'].median()/1000)
opnMD_list.append(df['OPN7_E'].median()/1000)
opnMD_list.append(df['OPN8_E'].median()/1000)
opnMD_list.append(df['OPN9_E'].median()/1000)
opnMD_list.append(df['OPN10_E'].median()/1000)

agrMD_list = []
agrMD_list.append(df['AGR1_E'].median()/1000)
agrMD_list.append(df['AGR2_E'].median()/1000)
agrMD_list.append(df['AGR3_E'].median()/1000)
agrMD_list.append(df['AGR4_E'].median()/1000)
agrMD_list.append(df['AGR5_E'].median()/1000)
agrMD_list.append(df['AGR6_E'].median()/1000)
agrMD_list.append(df['AGR7_E'].median()/1000)
agrMD_list.append(df['AGR8_E'].median()/1000)
agrMD_list.append(df['AGR9_E'].median()/1000)
agrMD_list.append(df['AGR10_E'].median()/1000)

estMD_list = []
estMD_list.append(df['EST1_E'].median()/1000)
estMD_list.append(df['EST2_E'].median()/1000)
estMD_list.append(df['EST3_E'].median()/1000)
estMD_list.append(df['EST4_E'].median()/1000)
estMD_list.append(df['EST5_E'].median()/1000)
estMD_list.append(df['EST6_E'].median()/1000)
estMD_list.append(df['EST7_E'].median()/1000)
estMD_list.append(df['EST8_E'].median()/1000)
estMD_list.append(df['EST9_E'].median()/1000)
estMD_list.append(df['EST10_E'].median()/1000)

# %%
avgTimeMD_list = pd.DataFrame(
    {'Extraversion': extMD_list,
     'Conscientiousness': csnMD_list,
     'Openness': opnMD_list,
     'Neuroticism': estMD_list,
     'Agreeableness': agrMD_list
    })

# %%
avgTimeMD_list
# Out:
#    Agreeableness  Conscientiousness  Extraversion  Neuroticism  Openness
# 0          4.362              3.516         7.340        3.283     3.026
# 1          3.260              4.241         3.418        3.595     4.254
# 2          3.160              3.195         3.484        2.784     2.752
# 3          3.177              3.321         3.479        3.597     3.739
# 4          4.067              3.569         3.006        3.496     2.831
# 5          2.862              4.361         3.113        3.162     3.337
# 6          3.699              2.891         4.350        3.146     3.208
# 7          3.820              3.765         3.630        2.940     3.051
# 8          3.122              2.876         3.652        2.773     3.269
# 9          3.334              3.925         3.225        2.567     2.192

# %%
avgTimeMD_list.max()
# Out:
# Agreeableness        4.362
# Conscientiousness    4.361
# Extraversion         7.340
# Neuroticism          3.597
# Openness             4.254
# dtype: float64

# %%
avgTimeMD_list.min()
# Out:
# Agreeableness        2.862
# Conscientiousness    2.876
# Extraversion         3.006
# Neuroticism          2.567
# Openness             2.192
# dtype: float64

# %%
total_time = []
for i in range(0,10):
    total_time.append(avgTimeMD_list.iloc[i].sum())

# %%
avgTimeMD_list = pd.DataFrame(
    {'Extraversion': extMD_list,
     'Conscientiousness': csnMD_list,
     'Openness': opnMD_list,
     'Neuroticism': estMD_list,
     'Agreeableness': agrMD_list,
     'Total Time for Row': total_time
    })

columnsTitles = ['Extraversion', 'Agreeableness', 'Conscientiousness', 'Neuroticism', 'Openness', 'Total Time for Row']
avgTimeMD_list = avgTimeMD_list.reindex(columns=columnsTitles)

# %%
avgTimeMD_list
# Out:
#    Extraversion  Agreeableness  Conscientiousness  Neuroticism  Openness  \
# 0         7.340          4.362              3.516        3.283     3.026
# 1         3.418          3.260              4.241        3.595     4.254
# 2         3.484          3.160              3.195        2.784     2.752
# 3         3.479          3.177              3.321        3.597     3.739
# 4         3.006          4.067              3.569        3.496     2.831
# 5         3.113          2.862              4.361        3.162     3.337
# 6         4.350          3.699              2.891        3.146     3.208
# 7         3.630          3.820              3.765        2.940     3.051
# 8         3.652          3.122              2.876        2.773     3.269
# 9         3.225          3.334              3.925        2.567     2.192
#
#    Total Time for Row
# 0              21.527
# 1              18.768
# 2              15.375
# 3              17.313
# 4              16.969
# 5              16.835
# ...

# %%
#Average time per question
total = 0 
for time in total_time:
    total += time
avg_time = total/10
avg_time
# Out:
# 17.2222

# %%
#Average time per Trait 
total = 0 
for time in extMD_list:
    total += time
est_avg_time = total/10
est_avg_time
# Out:
# 3.8696999999999995
